# %%
import pandas as pd 

df = pd.read_csv('../processed_data/tong_hop_dinh_duong.csv')
df.describe().T
# Out:
#                 count        mean         std  min     25%    50%    75%  \
# Carbohydrate   2184.0   45.644368   57.450323  0.0   22.75   35.0   60.0
# Calories       2184.0  625.038233  364.173666  0.0  417.50  550.0  750.0
# Protein        2184.0   44.241163   25.970117  0.0   28.00   45.0   55.0
# Sugar          2184.0   12.047848   18.183945  0.0    5.00    8.0   15.0
# Fiber dietary  2184.0    5.510943    3.894394  0.0    3.00    5.0    7.0
# Vitamin C      2184.0   26.795559   32.092400  0.0    8.00   20.0   30.0
# Vitamin D      2184.0    0.704670    2.280187  0.0    0.00    0.0    0.5
# Vitamin B12    2184.0    1.445788    2.567227  0.0    0.50    1.0    1.5
# Calcium        2184.0   87.977106   63.850729  0.0   50.00   80.0  100.0
# Iron           2184.0    3.709707    2.772694  0.0    2.00    3.0    4.0
# Cholesterol    2184.0  169.403388  170.309047  0.0   80.00  150.0  200.0
# Phosphorous    2184.0  330.180861  155.450896  0.0  250.00  300.0  400.0
# ...
